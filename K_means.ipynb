# %% [markdown]
# # K_means Clustering

# %% [markdown]
# Importing necessary libraries

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %% [markdown]
# Loding the data

# %%
data = pd.read_csv("iris.csv")

# %% [markdown]
# z score normalisation

# %%
def z_score_normalization(data):

  mean = np.mean(data, axis=0)
  std = np.std(data, axis=0)
  normalized_data = (data - mean) / std

  return normalized_data

# %% [markdown]
# normalise the data

# %%
features = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
normalized_data = z_score_normalization(data[features])

# %% [markdown]
# Applying PCA, Kmeans and Visualization

# %%
k = 2

# Step 1: Apply PCA for dimensionality reduction
pca = PCA(n_components=2)  # Reduce to 2 dimensions
data_reduced = pca.fit_transform(normalized_data)

# Step 2: Apply k-means clustering on the reduced data
kmeans = KMeans(n_clusters=k)
kmeans.fit(data_reduced)
cluster_labels = kmeans.labels_

# Step 3: Visualize the results
plt.scatter(data_reduced[:, 0], data_reduced[:, 1], c=cluster_labels, cmap='viridis', s=50)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('K-Means Clustering after PCA')
plt.show()
